# %%
import pandas as pd
import numpy as np
import scanpy as sc
import os
from matplotlib.pyplot import rc_context

import sys
import warnings

import scvi
import anndata
import matplotlib.pyplot as plt
# import scrublet as scr
# Out:
# Global seed set to 0

# %%
#set up directory
large_root = r"../data"
results_file = large_root + "/results_file.h5ad"

# %%
sc.set_figure_params(dpi=100, color_map = 'viridis_r')
sc.settings.verbosity = 1
sc.logging.print_header()
# Out:
# scanpy==1.9.2 anndata==0.8.0 umap==0.5.3 numpy==1.23.5 scipy==1.10.0 pandas==1.5.3 scikit-learn==1.2.1 statsmodels==0.13.5 python-igraph==0.10.4 pynndescent==0.5.4

# %%
index2 = pd.read_csv("../01-data/GSE120575_Sade_Feldman_melanoma_single_cells_TPM_GEO.txt", delimiter="\t",skiprows=[0], nrows=0).T

print(index2.shape)
index2 = index2.iloc[1:,:]
print(index2.shape)
index2 = index2.reset_index()
index2.rename(columns = {'index':'index2'}, inplace = True)

index2.head()
# adata = adata.iloc[1:,:].copy()
# adata.head()
# Out:
# (16292, 0)
# (16291, 0)
#      index2
# 0    Pre_P1
# 1  Pre_P1.1
# 2  Pre_P1.2
# 3  Pre_P1.3
# 4  Pre_P1.4

# %%
index3 = pd.read_csv("../01-data/GSE120575_Sade_Feldman_melanoma_single_cells_TPM_GEO.txt", delimiter="\t",skiprows=[1], nrows=0).T

print(index3.shape)
index3 = index3.iloc[1:,:]
print(index3.shape)
index3 = index3.reset_index()
index3.rename(columns = {'index':'index3'}, inplace = True)

index3.head()
# adata = adata.iloc[1:,:].copy()
# adata.head()
# Out:
# (16292, 0)
# (16291, 0)
#        index3
# 0  A10_P3_M11
# 1  A11_P1_M11
# 2  A11_P3_M11
# 3  A11_P4_M11
# 4  A12_P3_M11

# %%
index3
# Out:
#                           index3
# 0                     A10_P3_M11
# 1                     A11_P1_M11
# 2                     A11_P3_M11
# 3                     A11_P4_M11
# 4                     A12_P3_M11
# ...                          ...
# 16286  H5_P5_M67_L001_T_enriched
# 16287  H6_P5_M67_L001_T_enriched
# 16288  H7_P5_M67_L001_T_enriched
# 16289  H8_P5_M67_L001_T_enriched
# 16290  H9_P5_M67_L001_T_enriched
#
# [16291 rows x 1 columns]

# %%
index3_list = index3.index3.to_list()
len(index3_list)
index3_list = index3_list[:-1]
len(index3_list)
# Out:
# 16290

# %%
combo_index = pd.concat([index2, index3], axis="columns")
combo_index = combo_index.iloc[:-1,:]

# %%
combo_index['full_index'] = combo_index['index3'] + "-" +combo_index['index2']
combo_index = combo_index.drop('index2', axis = 1)
combo_index = combo_index.drop('index3', axis = 1)
combo_index = combo_index.set_index("full_index")
combo_index.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [A10_P3_M11-Pre_P1, A11_P1_M11-Pre_P1.1, A11_P3_M11-Pre_P1.2, A11_P4_M11-Pre_P1.3, A12_P3_M11-Pre_P1.4]

# %%
combo_index.shape
# Out:
# (16290, 0)

# %%
cell_names_list = combo_index.index.to_list()
print(len(cell_names_list))
# cell_names_list = cell_names_list[:-1]
print(len(cell_names_list))
cell_names_list
# Out:
# 16290
# 16290
# ['A10_P3_M11-Pre_P1',
#  'A11_P1_M11-Pre_P1.1',
#  'A11_P3_M11-Pre_P1.2',
#  'A11_P4_M11-Pre_P1.3',
#  'A12_P3_M11-Pre_P1.4',
#  'A12_P6_M11-Pre_P1.5',
#  'A2_P1_M11-Pre_P1.6',
#  'A2_P4_M11-Pre_P1.7',
#  'A3_P1_M11-Pre_P1.8',
#  'A3_P3_M11-Pre_P1.9',
#  'A4_P3_M11-Pre_P1.10',
#  'A4_P4_M11-Pre_P1.11',
#  'A4_P6_M11-Pre_P1.12',
#  'A5_P4_M11-Pre_P1.13',
#  'A5_P5_M11-Pre_P1.14',
#  'A6_P1_M11-Pre_P1.15',
#  'A6_P4_M11-Pre_P1.16',
#  'A6_P6_M11-Pre_P1.17',
#  'A7_P2_M11-Pre_P1.18',
#  'A7_P6_M11-Pre_P1.19',
#  'A8_P1_M11-Pre_P1.20',
#  'A8_P6_M11-Pre_P1.21',
#  'A9_P1_M11-Pre_P1.22',
#  'A9_P4_M11-Pre_P1.23',
#  'B10_P1_M11-Pre_P1.24',
#  'B10_P3_M11-Pre_P1.25',
#  'B10_P4_M11-Pre_P1.26',
#  'B10_P6_M11-Pre_P1.27',
#  'B11_P6_M11-Pre_P1.28',
#  'B12_P3_M11-Pre_P1.29',
#  'B12_P4_M11-Pre_P1.30',
#  'B1_P2_M11-Pre_P1.31',
#  'B1_P4_M11-Pre_P1.32',
#  'B2_P1_M11-Pre_P1.33',
#  'B2_P5_M11-Pre_P1.34',
#  'B2_P6_M11-Pre_P1.35',
#  'B3_P1_M11-Pre_P1.36',
#  'B3_P5_M11-Pre_P1.37',
#  'B4_P1_M11-Pre_P1.38',
#  'B4_P4_M11-Pre_P1.39',
#  'B4_P6_M11-Pre_P1.40',
#  'B5_P1_M11-Pre_P1.41',
#  'B5_P6_M11-Pre_P1.42',
#  'B6_P1_M11-Pre_P1.43',
#  'B7_P4_M11-Pre_P1.44',
#  'B8_P6_M11-Pre_P1.45',
#  'B9_P2_M11-Pre_P1.46',
#  'C10_P4_M11-Pre_P1.47',
#  'C10_P6_M11-Pre_P1.48',
#  'C11_P4_M11-Pre_P1.49',
#  'C11_P6_M11-Pre_P1.50',
#  'C12_P4_M11-Pre_P1.51',
#  'C1_P3_M11-Pre_P1.52',
#  'C1_P4_M11-Pre_P1.53',
#  'C2_P6_M11-Pre_P1.54',
#  'C3_P1_M11-Pre_P1.55',
#  'C4_P1_M11-Pre_P1.56',
#  'C4_P3_M11-Pre_P1.57',
#  'C4_P4_M11-Pre_P1.58',
#  'C4_P6_M11-Pre_P1.59',
#  'C5_P3_M11-Pre_P1.60',
#  'C5_P5_M11-Pre_P1.61',
#  'C5_P6_M11-Pre_P1.62',
#  'C6_P2_M11-Pre_P1.63',
#  'C6_P3_M11-Pre_P1.64',
#  'C6_P4_M11-Pre_P1.65',
#  'C7_P3_M11-Pre_P1.66',
#  'C7_P5_M11-Pre_P1.67',
#  'C7_P6_M11-Pre_P1.68',
#  'C8_P3_M11-Pre_P1.69',
#  'C8_P5_M11-Pre_P1.70',
#  'C9_P1_M11-Pre_P1.71',
#  'C9_P2_M11-Pre_P1.72',
#  'F3_P4_M11-Pre_P1.144',
#  'F3_P5_M11-Pre_P1.145',
#  'F4_P1_M11-Pre_P1.146',
#  'F4_P3_M11-Pre_P1.147',
#  'F4_P5_M11-Pre_P1.148',
#  'F4_P6_M11-Pre_P1.149',
#  'F5_P1_M11-Pre_P1.150',
#  'F5_P5_M11-Pre_P1.151',
#  'F6_P1_M11-Pre_P1.152',
#  'F6_P2_M11-Pre_P1.153',
#  'F6_P4_M11-Pre_P1.154',
#  'F6_P5_M11-Pre_P1.155',
#  'F7_P1_M11-Pre_P1.156',
#  'F7_P2_M11-Pre_P1.157',
#  'F7_P3_M11-Pre_P1.158',
#  'F8_P1_M11-Pre_P1.159',
#  'F8_P2_M11-Pre_P1.160',
#  'F8_P3_M11-Pre_P1.161',
#  'F8_P4_M11-Pre_P1.162',
#  'F8_P5_M11-Pre_P1.163',
#  'F9_P1_M11-Pre_P1.164',
#  'F9_P4_M11-Pre_P1.165',
#  'F9_P6_M11-Pre_P1.166',
#  'G10_P3_M11-Pre_P1.167',
#  'G10_P5_M11-Pre_P1.168',
#  'G10_P6_M11-Pre_P1.169',
#  'G11_P3_M11-Pre_P1.170',
#  'G11_P6_M11-Pre_P1.171',
#  'G12_P3_M11-Pre_P1.172',
#  'G12_P4_M11-Pre_P1.173',
#  'G12_P5_M11-Pre_P1.174',
#  'G12_P6_M11-Pre_P1.175',
#  'G1_P1_M11-Pre_P1.176',
#  'G1_P2_M11-Pre_P1.177',
#  'G1_P3_M11-Pre_P1.178',
#  'G1_P4_M11-Pre_P1.179',
#  'G2_P1_M11-Pre_P1.180',
#  'G2_P3_M11-Pre_P1.181',
#  'G2_P5_M11-Pre_P1.182',
#  'G2_P6_M11-Pre_P1.183',
#  'G3_P3_M11-Pre_P1.184',
#  'G3_P4_M11-Pre_P1.185',
#  'G3_P6_M11-Pre_P1.186',
#  'G4_P3_M11-Pre_P1.187',
#  'G4_P4_M11-Pre_P1.188',
#  'G4_P6_M11-Pre_P1.189',
#  'G5_P4_M11-Pre_P1.190',
#  'G5_P6_M11-Pre_P1.191',
#  'G6_P1_M11-Pre_P1.192',
#  'G6_P2_M11-Pre_P1.193',
#  'G6_P3_M11-Pre_P1.194',
#  'G6_P4_M11-Pre_P1.195',
#  'G6_P6_M11-Pre_P1.196',
#  'G7_P2_M11-Pre_P1.197',
#  'G7_P4_M11-Pre_P1.198',
#  'G7_P6_M11-Pre_P1.199',
#  'G8_P2_M11-Pre_P1.200',
#  'G8_P3_M11-Pre_P1.201',
#  'G8_P6_M11-Pre_P1.202',
#  'G9_P1_M11-Pre_P1.203',
#  'G9_P3_M11-Pre_P1.204',
#  'G9_P6_M11-Pre_P1.205',
#  'H12_P3_M11-Pre_P1.206',
#  'H1_P1_M11-Pre_P1.207',
#  'H1_P4_M11-Pre_P1.208',
#  'H2_P4_M11-Pre_P1.209',
#  'H3_P1_M11-Pre_P1.210',
#  'H3_P2_M11-Pre_P1.211',
#  'H3_P4_M11-Pre_P1.212',
#  'H3_P5_M11-Pre_P1.213',
#  'H3_P6_M11-Pre_P1.214',
#  'H4_P2_M11-Pre_P1.215',
#  'H4_P5_M11-Pre_P1.216',
#  'H4_P6_M11-Pre_P1.217',
#  'H6_P3_M11-Pre_P1.218',
#  'H6_P4_M11-Pre_P1.219',
#  'H7_P3_M11-Pre_P1.220',
#  'H7_P4_M11-Pre_P1.221',
#  'H8_P1_M11-Pre_P1.222',
#  'H8_P5_M11-Pre_P1.223',
#  'H9_P1_M11-Pre_P1.224',
#  'H9_P3_M11-Pre_P1.225',
#  'H9_P4_M11-Pre_P1.226',
#  'H9_P5_M11-Pre_P1.227',
#  'H9_P6_M11-Pre_P1.228',
#  'A10_P1_M15-Post_P1',
#  'A10_P4_M15-Post_P1.1',
#  'A10_P5_M15-Post_P1.2',
#  'A10_P6_M15-Post_P1.3',
#  'A11_P1_M15-Post_P1.4',
#  'A11_P2_M15-Post_P1.5',
#  'A11_P5_M15-Post_P1.6',
#  'A11_P6_M15-Post_P1.7',
#  'A12_P1_M15-Post_P1.8',
#  'A12_P2_M15-Post_P1.9',
#  'A12_P5_M15-Post_P1.10',
#  'A2_P1_M15-Post_P1.11',
#  'A2_P2_M15-Post_P1.12',
#  'A2_P3_M15-Post_P1.13',
#  'A2_P6_M15-Post_P1.14',
#  'A3_P2_M15-Post_P1.15',
#  'A3_P6_M15-Post_P1.16',
#  'A4_P1_M15-Post_P1.17',
#  'A4_P3_M15-Post_P1.18',
#  'A4_P4_M15-Post_P1.19',
#  'A4_P5_M15-Post_P1.20',
#  'A4_P6_M15-Post_P1.21',
#  'A5_P1_M15-Post_P1.22',
#  'A5_P5_M15-Post_P1.23',
#  'A5_P6_M15-Post_P1.24',
#  'A6_P1_M15-Post_P1.25',
#  'A6_P2_M15-Post_P1.26',
#  'A7_P1_M15-Post_P1.27',
#  'A7_P2_M15-Post_P1.28',
#  'A8_P1_M15-Post_P1.29',
#  'A8_P2_M15-Post_P1.30',
#  'A9_P1_M15-Post_P1.31',
#  'B10_P1_M15-Post_P1.32',
#  'B10_P2_M15-Post_P1.33',
#  'B10_P4_M15-Post_P1.34',
#  'B10_P5_M15-Post_P1.35',
#  'B11_P1_M15-Post_P1.36',
#  'B11_P2_M15-Post_P1.37',
#  'B11_P6_M15-Post_P1.38',
#  'B12_P1_M15-Post_P1.39',
#  'B12_P2_M15-Post_P1.40',
#  'B12_P5_M15-Post_P1.41',
#  'B1_P1_M15-Post_P1.42',
#  'B1_P2_M15-Post_P1.43',
#  'B1_P4_M15-Post_P1.44',
#  'B2_P1_M15-Post_P1.45',
#  'B2_P2_M15-Post_P1.46',
#  'B2_P6_M15-Post_P1.47',
#  'B3_P1_M15-Post_P1.48',
#  'B3_P2_M15-Post_P1.49',
#  'B3_P3_M15-Post_P1.50',
#  'B3_P5_M15-Post_P1.51',
#  'B3_P6_M15-Post_P1.52',
#  'B4_P2_M15-Post_P1.53',
#  'B4_P3_M15-Post_P1.54',
#  'B5_P1_M15-Post_P1.55',
#  'B5_P5_M15-Post_P1.56',
#  'B6_P1_M15-Post_P1.57',
#  'B6_P6_M15-Post_P1.58',
#  'B7_P1_M15-Post_P1.59',
#  'B7_P6_M15-Post_P1.60',
#  'B8_P2_M15-Post_P1.61',
#  'B9_P2_M15-Post_P1.62',
#  'B9_P6_M15-Post_P1.63',
#  'C10_P2_M15-Post_P1.64',
#  'C10_P4_M15-Post_P1.65',
#  'C11_P1_M15-Post_P1.66',
#  'C11_P2_M15-Post_P1.67',
#  'C11_P3_M15-Post_P1.68',
#  'C11_P5_M15-Post_P1.69',
#  'C11_P6_M15-Post_P1.70',
#  'C12_P1_M15-Post_P1.71',
#  'C12_P2_M15-Post_P1.72',
#  'C12_P5_M15-Post_P1.73',
#  'C12_P6_M15-Post_P1.74',
#  'C1_P1_M15-Post_P1.75',
#  'C1_P2_M15-Post_P1.76',
#  'C1_P6_M15-Post_P1.77',
#  'C2_P1_M15-Post_P1.78',
#  'C2_P2_M15-Post_P1.79',
#  'C2_P3_M15-Post_P1.80',
#  'C2_P6_M15-Post_P1.81',
#  'C3_P2_M15-Post_P1.82',
#  'C3_P6_M15-Post_P1.83',
#  'C4_P1_M15-Post_P1.84',
#  'C4_P2_M15-Post_P1.85',
#  'C4_P3_M15-Post_P1.86',
#  'C4_P6_M15-Post_P1.87',
#  'C5_P1_M15-Post_P1.88',
#  'C5_P2_M15-Post_P1.89',
#  'C5_P5_M15-Post_P1.90',
#  'C5_P6_M15-Post_P1.91',
#  'C6_P1_M15-Post_P1.92',
#  'C6_P2_M15-Post_P1.93',
#  'C6_P5_M15-Post_P1.94',
#  'C6_P6_M15-Post_P1.95',
#  'C7_P1_M15-Post_P1.96',
#  'C8_P1_M15-Post_P1.97',
#  'C8_P2_M15-Post_P1.98',
#  'C8_P6_M15-Post_P1.99',
#  'C9_P1_M15-Post_P1.100',
#  'C9_P5_M15-Post_P1.101',
#  'D10_P1_M15-Post_P1.102',
#  'D10_P2_M15-Post_P1.103',
#  'D10_P4_M15-Post_P1.104',
#  'D10_P5_M15-Post_P1.105',
#  'D10_P6_M15-Post_P1.106',
#  'D11_P1_M15-Post_P1.107',
#  'D11_P2_M15-Post_P1.108',
#  'D11_P3_M15-Post_P1.109',
#  'D11_P5_M15-Post_P1.110',
#  'D11_P6_M15-Post_P1.111',
#  'D12_P1_M15-Post_P1.112',
#  'D12_P2_M15-Post_P1.113',
#  'D12_P5_M15-Post_P1.114',
#  'D1_P1_M15-Post_P1.115',
#  'D1_P2_M15-Post_P1.116',
#  'D1_P4_M15-Post_P1.117',
#  'D1_P6_M15-Post_P1.118',
#  'D2_P2_M15-Post_P1.119',
#  'D2_P3_M15-Post_P1.120',
#  'D2_P5_M15-Post_P1.121',
#  'D3_P1_M15-Post_P1.122',
#  'D3_P2_M15-Post_P1.123',
#  'D3_P5_M15-Post_P1.124',
#  'D3_P6_M15-Post_P1.125',
#  'D4_P2_M15-Post_P1.126',
#  'D4_P3_M15-Post_P1.127',
#  'D4_P5_M15-Post_P1.128',
#  'D4_P6_M15-Post_P1.129',
#  'D5_P1_M15-Post_P1.130',
#  'D5_P2_M15-Post_P1.131',
#  'D5_P3_M15-Post_P1.132',
#  'D5_P6_M15-Post_P1.133',
#  'D6_P1_M15-Post_P1.134',
#  'D6_P2_M15-Post_P1.135',
#  'D6_P5_M15-Post_P1.136',
#  'D6_P6_M15-Post_P1.137',
#  'D7_P1_M15-Post_P1.138',
#  'D7_P2_M15-Post_P1.139',
#  'D7_P4_M15-Post_P1.140',
#  'D7_P5_M15-Post_P1.141',
#  'D8_P1_M15-Post_P1.142',
#  'D8_P5_M15-Post_P1.143',
#  'D8_P6_M15-Post_P1.144',
#  'D9_P1_M15-Post_P1.145',
#  'D9_P2_M15-Post_P1.146',
#  'E10_P1_M15-Post_P1.147',
#  'E10_P2_M15-Post_P1.148',
#  'E10_P5_M15-Post_P1.149',
#  'E10_P6_M15-Post_P1.150',
#  'E11_P1_M15-Post_P1.151',
#  'E11_P2_M15-Post_P1.152',
#  'E11_P3_M15-Post_P1.153',
#  'E11_P5_M15-Post_P1.154',
#  'E11_P6_M15-Post_P1.155',
#  'E12_P1_M15-Post_P1.156',
#  'E12_P2_M15-Post_P1.157',
#  'E12_P4_M15-Post_P1.158',
#  'E12_P5_M15-Post_P1.159',
#  'E12_P6_M14-Post_P1.160',
#  'E1_P1_M15-Post_P1.161',
#  'E1_P2_M15-Post_P1.162',
#  'E1_P4_m15-Post_P1.163',
#  'E1_P5_M15-Post_P1.164',
#  'E2_P1_M15-Post_P1.165',
#  'E2_P2_M15-Post_P1.166',
#  'E2_P6_M15-Post_P1.167',
#  'E3_P1_M15-Post_P1.168',
#  'E3_P6_M15-Post_P1.169',
#  'E4_P1_M15-Post_P1.170',
#  'E4_P2_M15-Post_P1.171',
#  'E4_P5_M15-Post_P1.172',
#  'E5_P2_M15-Post_P1.173',
#  'E5_P6_M15-Post_P1.174',
#  'E6_P5_M15-Post_P1.175',
#  'E7_P1_M15-Post_P1.176',
#  'E8_P2_M15-Post_P1.177',
#  'E8_P6_M15-Post_P1.178',
#  'E9_P1_M15-Post_P1.179',
#  'E9_P6_M15-Post_P1.180',
#  'F10_P1_M15-Post_P1.181',
#  'F10_P2_M15-Post_P1.182',
#  'F10_P5_M15-Post_P1.183',
#  'F10_P6_M15-Post_P1.184',
#  'F11_P1_M15-Post_P1.185',
#  'F11_P2_M15-Post_P1.186',
#  'F11_P5_M15-Post_P1.187',
#  'F12_P1_M15-Post_P1.188',
#  'F12_P2_M15-Post_P1.189',
#  'F12_P6_M14-Post_P1.190',
#  'F1_P1_M15-Post_P1.191',
#  'F1_P2_M15-Post_P1.192',
#  'F1_P4_M15-Post_P1.193',
#  'F1_P6_M15-Post_P1.194',
#  'F2_P1_M15-Post_P1.195',
#  'F2_P5_M15-Post_P1.196',
#  'F2_P6_M15-Post_P1.197',
#  'F3_P1_M15-Post_P1.198',
#  'F3_P4_M15-Post_P1.199',
#  'F3_P5_M15-Post_P1.200',
#  'F3_P6_M15-Post_P1.201',
#  'F4_P5_M15-Post_P1.202',
#  'F5_P1_M15-Post_P1.203',
#  'F5_P5_M15-Post_P1.204',
#  'F6_P2_M15-Post_P1.205',
#  'F6_P3_M15-Post_P1.206',
#  'F6_P5_M15-Post_P1.207',
#  'F6_P6_M15-Post_P1.208',
#  'F7_P1_M15-Post_P1.209',
#  'F7_P6_M15-Post_P1.210',
#  'F8_P5_M15-Post_P1.211',
#  'F8_P6_M15-Post_P1.212',
#  'F9_P6_M15-Post_P1.213',
#  'G10_P1_M15-Post_P1.214',
#  'G10_P6_M15-Post_P1.215',
#  'G11_P1_M15-Post_P1.216',
#  'G11_P5_M15-Post_P1.217',
#  'G11_P6_M15-Post_P1.218',
#  'G12_P1_M15-Post_P1.219',
#  'G12_P2_M15-Post_P1.220',
#  'G12_P6_M14-Post_P1.221',
#  'G1_P1_M15-Post_P1.222',
#  'G1_P2_M15-Post_P1.223',
#  'G1_P4_M15-Post_P1.224',
#  'G1_P5_M15-Post_P1.225',
#  'G1_P6_M15-Post_P1.226',
#  'G2_P1_M15-Post_P1.227',
#  'G2_P2_M15-Post_P1.228',
#  'G3_P1_M15-Post_P1.229',
#  'G3_P3_M15-Post_P1.230',
#  'G3_P4_M15-Post_P1.231',
#  'G3_P5_M15-Post_P1.232',
#  'G3_P6_M15-Post_P1.233',
#  'G4_P1_M15-Post_P1.234',
#  'G4_P2_M15-Post_P1.235',
#  'G4_P5_M15-Post_P1.236',
#  'G5_P1_M15-Post_P1.237',
#  'G5_P6_M15-Post_P1.238',
#  'G6_P2_M15-Post_P1.239',
#  'G6_P5_M15-Post_P1.240',
#  'G6_P6_M15-Post_P1.241',
#  'G7_P5_M15-Post_P1.242',
#  'G7_P6_M15-Post_P1.243',
#  'G8_P1_M15-Post_P1.244',
#  'G8_P2_M15-Post_P1.245',
#  'G8_P5_M15-Post_P1.246',
#  'G8_P6_M15-Post_P1.247',
#  'G9_P1_M15-Post_P1.248',
#  'G9_P5_M15-Post_P1.249',
#  'G9_P6_M15-Post_P1.250',
#  'H10_P1_M15-Post_P1.251',
#  'H10_P2_M15-Post_P1.252',
#  'H10_P4_M15-Post_P1.253',
#  'H10_P5_M15-Post_P1.254',
#  'H10_P6_M15-Post_P1.255',
#  'H11_P1_M15-Post_P1.256',
#  'H11_P2_M15-Post_P1.257',
#  'H11_P3_M15-Post_P1.258',
#  'H11_P6_M15-Post_P1.259',
#  'H12_P1_M15-Post_P1.260',
#  'H12_P2_M15-Post_P1.261',
#  'H12_P5_M15-Post_P1.262',
#  'H12_P6_M14-Post_P1.263',
#  'H1_P1_M15-Post_P1.264',
#  'H1_P2_M15-Post_P1.265',
#  'H1_P4_M15-Post_P1.266',
#  'H1_P6_M15-Post_P1.267',
#  'H2_P1_M15-Post_P1.268',
#  'H2_P2_M15-Post_P1.269',
#  'H2_P3_M15-Post_P1.270',
#  'H2_P6_M15-Post_P1.271',
#  'H3_P1_M15-Post_P1.272',
#  'H3_P6_M15-Post_P1.273',
#  'H4_P2_M15-Post_P1.274',
#  'H4_P6_M15-Post_P1.275',
#  'H5_P1_M15-Post_P1.276',
#  'H5_P5_M15-Post_P1.277',
#  'H5_P6_M15-Post_P1.278',
#  'H6_P1_M15-Post_P1.279',
#  'H6_P3_M15-Post_P1.280',
#  'H6_P6_M15-Post_P1.281',
#  'H7_P1_M15-Post_P1.282',
#  'H7_P2_M15-Post_P1.283',
#  'A11_P1_M34-Pre_P2.4',
#  'A11_P2_M34-Pre_P2.5',
#  'A11_P3_M34-Pre_P2.6',
#  'A11_P4_M34-Pre_P2.7',
#  'A12_P1_M34-Pre_P2.8',
#  'A12_P2_M34-Pre_P2.9',
#  'A12_P3_M34-Pre_P2.10',
#  'A12_P4_M34-Pre_P2.11',
#  'A2_P2_M34-Pre_P2.12',
#  'A2_P3_M34-Pre_P2.13',
#  'A2_P4_M34-Pre_P2.14',
#  'A3_P1_M34-Pre_P2.15',
#  'A3_P2_M34-Pre_P2.16',
#  'A3_P4_M34-Pre_P2.17',
#  'A4_P1_M34-Pre_P2.18',
#  'A4_P2_M34-Pre_P2.19',
#  'A4_P3_M34-Pre_P2.20',
#  'A4_P4_M34-Pre_P2.21',
#  'A5_P1_M34-Pre_P2.22',
#  'A5_P2_M34-Pre_P2.23',
#  'A5_P3_M34-Pre_P2.24',
#  'A5_P4_M34-Pre_P2.25',
#  'A6_P1_M34-Pre_P2.26',
#  'A6_P2_M34-Pre_P2.27',
#  'A6_P3_M34-Pre_P2.28',
#  'A6_P4_M34-Pre_P2.29',
#  'A7_P1_M34-Pre_P2.30',
#  'A7_P2_M34-Pre_P2.31',
#  'A7_P3_M34-Pre_P2.32',
#  'A7_P4_M34-Pre_P2.33',
#  'A8_P1_M34-Pre_P2.34',
#  'A8_P2_M34-Pre_P2.35',
#  'A8_P3_M34-Pre_P2.36',
#  'A8_P4_M34-Pre_P2.37',
#  'A9_P1_M34-Pre_P2.38',
#  'A9_P2_M34-Pre_P2.39',
#  'A9_P3_M34-Pre_P2.40',
#  'A9_P4_M34-Pre_P2.41',
#  'B10_P1_M34-Pre_P2.42',
#  'B10_P3_M34-Pre_P2.43',
#  'B10_P4_M34-Pre_P2.44',
#  'B11_P1_M34-Pre_P2.45',
#  'B11_P2_M34-Pre_P2.46',
#  'B11_P4_M15-Pre_P2.47',
#  'B12_P1_M34-Pre_P2.48',
#  'B12_P2_M34-Pre_P2.49',
#  'B12_P4_M34-Pre_P2.50',
#  'B1_P1_M34-Pre_P2.51',
#  'B1_P2_M34-Pre_P2.52',
#  'B1_P3_M34-Pre_P2.53',
#  'B1_P4_M34-Pre_P2.54',
#  'B2_P1_M34-Pre_P2.55',
#  'B2_P2_M34-Pre_P2.56',
#  'B2_P3_M34-Pre_P2.57',
#  'B2_P4_M34-Pre_P2.58',
#  'B3_P1_M34-Pre_P2.59',
#  'B3_P2_M34-Pre_P2.60',
#  'B3_P3_M34-Pre_P2.61',
#  'B3_P4_M34-Pre_P2.62',
#  'B4_P1_M34-Pre_P2.63',
#  'B4_P2_M34-Pre_P2.64',
#  'B4_P3_M34-Pre_P2.65',
#  'B4_P4_M34-Pre_P2.66',
#  'B5_P1_M34-Pre_P2.67',
#  'B5_P2_M34-Pre_P2.68',
#  'B5_P3_M34-Pre_P2.69',
#  'B5_P4_M34-Pre_P2.70',
#  'B6_P1_M34-Pre_P2.71',
#  'B6_P2_M34-Pre_P2.72',
#  'B6_P3_M34-Pre_P2.73',
#  'B6_P4_M34-Pre_P2.74',
#  'B7_P1_M34-Pre_P2.75',
#  'B7_P2_M34-Pre_P2.76',
#  'B7_P3_M34-Pre_P2.77',
#  'B7_P4_M34-Pre_P2.78',
#  'B8_P1_M34-Pre_P2.79',
#  'B8_P2_M34-Pre_P2.80',
#  'B8_P3_M34-Pre_P2.81',
#  'B8_P4_M34-Pre_P2.82',
#  'B9_P1_M34-Pre_P2.83',
#  'B9_P2_M34-Pre_P2.84',
#  'B9_P3_M34-Pre_P2.85',
#  'B9_P4_M34-Pre_P2.86',
#  'C10_P1_M34-Pre_P2.87',
#  'C10_P2_M34-Pre_P2.88',
#  'C10_P3_M34-Pre_P2.89',
#  'C10_P4_M34-Pre_P2.90',
#  'C11_P1_M34-Pre_P2.91',
#  'C11_P2_M34-Pre_P2.92',
#  'C11_P3_M34-Pre_P2.93',
#  'C11_P4_M34-Pre_P2.94',
#  'C12_P1_M34-Pre_P2.95',
#  'C12_P2_M34-Pre_P2.96',
#  'C12_P3_M34-Pre_P2.97',
#  'C12_P4_M34-Pre_P2.98',
#  'C1_P1_M34-Pre_P2.99',
#  'C1_P2_M34-Pre_P2.100',
#  'C1_P3_M34-Pre_P2.101',
#  'C1_P4_M34-Pre_P2.102',
#  'C2_P1_M34-Pre_P2.103',
#  'C2_P2_M34-Pre_P2.104',
#  'C2_P3_M34-Pre_P2.105',
#  'C3_P1_M34-Pre_P2.106',
#  'C3_P2_M34-Pre_P2.107',
#  'C3_P3_M34-Pre_P2.108',
#  'C3_P4_M34-Pre_P2.109',
#  'C4_P3_M34-Pre_P2.110',
#  'C4_P4_M34-Pre_P2.111',
#  'C5_P2_M34-Pre_P2.112',
#  'C5_P3_M34-Pre_P2.113',
#  'C5_P4_M34-Pre_P2.114',
#  'C6_P1_M34-Pre_P2.115',
#  'C6_P2_M34-Pre_P2.116',
#  'C6_P3_M34-Pre_P2.117',
#  'C6_P4_M34-Pre_P2.118',
#  'C7_P1_M34-Pre_P2.119',
#  'C7_P2_M34-Pre_P2.120',
#  'C7_P3_M34-Pre_P2.121',
#  'C7_P4_M34-Pre_P2.122',
#  'C8_P1_M34-Pre_P2.123',
#  'C8_P2_M34-Pre_P2.124',
#  'C8_P3_M34-Pre_P2.125',
#  'C8_P4_M34-Pre_P2.126',
#  ...]

# %%
gene_names = pd.read_csv("../01-data/GSE120575_Sade_Feldman_melanoma_single_cells_TPM_GEO.txt", delimiter="\t", usecols=[0])
# print("gene names: "gene_names[0])

gene_names.rename(columns = {'Unnamed: 0':'gene_names'}, inplace = True)
gene_names_list = gene_names.gene_names.to_list()
print(gene_names_list[0])

gene_names_list = gene_names_list[1:]
gene_names_list
# Out:
# nan
# ['TSPAN6',
#  'TNMD',
#  'DPM1',
#  'SCYL3',
#  'C1orf112',
#  'FGR',
#  'CFH',
#  'FUCA2',
#  'GCLC',
#  'NFYA',
#  'STPG1',
#  'NIPAL3',
#  'LAS1L',
#  'ENPP4',
#  'SEMA3F',
#  'CFTR',
#  'ANKIB1',
#  'CYP51A1',
#  'KRIT1',
#  'RAD52',
#  'MYH16',
#  'BAD',
#  'LAP3',
#  'CD99',
#  'HS3ST1',
#  'AOC1',
#  'WNT16',
#  'HECW1',
#  'MAD1L1',
#  'LASP1',
#  'SNX11',
#  'TMEM176A',
#  'M6PR',
#  'KLHL13',
#  'CYP26B1',
#  'ICA1',
#  'DBNDD1',
#  'ALS2',
#  'CASP10',
#  'CFLAR',
#  'TFPI',
#  'NDUFAF7',
#  'RBM5',
#  'MTMR7',
#  'SLC7A2',
#  'ARF5',
#  'SARM1',
#  'POLDIP2',
#  'PLXND1',
#  'AK2',
#  'CD38',
#  'FKBP4',
#  'KDM1A',
#  'RBM6',
#  'CAMKK1',
#  'RECQL',
#  'CCDC132',
#  'HSPB6',
#  'ARHGAP33',
#  'NDUFAB1',
#  'PDK4',
#  'SLC22A16',
#  'ZMYND10',
#  'ABCB5',
#  'ARX',
#  'SLC25A13',
#  'ST7',
#  'CDC27',
#  'SLC4A1',
#  'CALCR',
#  'HCCS',
#  'DVL2',
#  'PRSS22',
#  'UPF1',
#  'SKAP2',
#  'SLC25A5',
#  'CCDC109B',
#  'HOXA11',
#  'POLR2J',
#  'DHX33',
#  'MEOX1',
#  'THSD7A',
#  'LIG3',
#  'RPAP3',
#  'ACSM3',
#  'AC004381.6',
#  'CIAPIN1',
#  'SPPL2B',
#  'FAM214B',
#  'COPZ2',
#  'PRKAR2B',
#  'MSL3',
#  'CREBBP',
#  'BZRAP1',
#  'MPO',
#  'PON1',
#  'GCFC2',
#  'WDR54',
#  'CROT',
#  'ABCB4',
#  'KMT2E',
#  'RHBDD2',
#  'SOX8',
#  'IBTK',
#  'ZNF195',
#  'MYCBP2',
#  'FBXL3',
#  'ITGAL',
#  'PDK2',
#  'ITGA3',
#  'ZFX',
#  'LAMP2',
#  'GGNBP2',
#  'ITGA2B',
#  'ASB4',
#  'GDE1',
#  'C19orf60',
#  'CRLF1',
#  'OSBPL7',
#  'TMEM98',
#  'YBX2',
#  'KRT33A',
#  'MAP3K14',
#  'ABCC8',
#  'CCL18',
#  'CCL3',
#  'SYNRG',
#  'CACNG3',
#  'TMEM132A',
#  'AP2B1',
#  'TAC1',
#  'ZNF263',
#  'CX3CL1',
#  'SPATA20',
#  'CACNA1G',
#  'TNFRSF12A',
#  'DLX6',
#  'MAP3K9',
#  'RALA',
#  'BAIAP2L1',
#  'JHDM1D',
#  'ETV1',
#  'AGK',
#  'ALDH3B1',
#  'TTC22',
#  'PHTF2',
#  'CCL26',
#  'FARP2',
#  'USH1C',
#  'GGCT',
#  'DBF4',
#  'TBXA2R',
#  'IFRD1',
#  'LGALS14',
#  'COX10',
#  'GTF2IRD1',
#  'PAF1',
#  'VPS41',
#  'ARHGAP44',
#  'ELAC2',
#  'SCIN',
#  'ARSD',
#  'PNPLA4',
#  'MYH13',
#  'ADIPOR2',
#  'CDKL3',
#  'UPP2',
#  'PRSS21',
#  'MARK4',
#  'PROM1',
#  'CCDC124',
#  'CEACAM21',
#  'PAFAH1B1',
#  'NOS2',
#  'DNAH9',
#  'KIAA0100',
#  'SLC13A2',
#  'GAS7',
#  'TRAPPC6A',
#  'MATK',
#  'CEACAM7',
#  'CD79B',
#  'SCN4A',
#  'ST7L',
#  'TKTL1',
#  'PAX6',
#  'RPUSD1',
#  'RHBDF1',
#  'LUC7L',
#  'CACNA2D2',
#  'BAIAP3',
#  'TSR3',
#  'PIGQ',
#  'CRAMP1L',
#  'TEAD3',
#  'SELE',
#  'DNAJC11',
#  'FMO3',
#  'MYLIP',
#  'NOX1',
#  'E2F2',
#  'PSMB1',
#  'SYN1',
#  'JARID2',
#  'CDKL5',
#  'CAMK1G',
#  'CDK11A',
#  'NADK',
#  'TFAP2B',
#  'TFAP2D',
#  'DLEC1',
#  'CYTH3',
#  'ADAM22',
#  'SYPL1',
#  'CYB561',
#  'SPAG9',
#  'CELSR3',
#  'AASS',
#  'PLEKHG6',
#  'SS18L2',
#  'MPND',
#  'MGST1',
#  'CRY1',
#  'PGLYRP1',
#  'NFIX',
#  'ST3GAL1',
#  'MMP25',
#  'IL32',
#  'PKD1',
#  'MAPK8IP2',
#  'MED24',
#  'RHOBTB2',
#  'HEATR5B',
#  'SEC62',
#  'RPS20',
#  'CSDE1',
#  'UBE3C',
#  'REV3L',
#  'TENM1',
#  'PAX7',
#  'MASP2',
#  'IYD',
#  'FAM76A',
#  'TRAF3IP3',
#  'POMT2',
#  'VTA1',
#  'MLXIPL',
#  'BAZ1B',
#  'RANBP9',
#  'ETV7',
#  'SPRTN',
#  'METTL13',
#  'DYRK4',
#  'ZNF207',
#  'UQCRC1',
#  'STARD3NL',
#  'CD9',
#  'HHATL',
#  'NCAPD2',
#  'IFFO1',
#  'GIPR',
#  'PHF7',
#  'SEMA3G',
#  'NISCH',
#  'STAB1',
#  'FUZ',
#  'SLC6A13',
#  'IDS',
#  'PRSS3',
#  'ZNF200',
#  'CD4',
#  'LRRC23',
#  'BTK',
#  'HFE',
#  'SCMH1',
#  'FYN',
#  'HIVEP2',
#  'FMO1',
#  'TCEB3',
#  'LYPLA2',
#  'CLCN6',
#  'MRC2',
#  'NME2',
#  'SLC6A7',
#  'TSPAN9',
#  'BTBD7',
#  'APBA3',
#  'MKS1',
#  'ABHD5',
#  'KAL1',
#  'AKAP8L',
#  'MBTD1',
#  'UTP18',
#  'RNF216',
#  'TTC19',
#  'PTBP1',
#  'DPF1',
#  'SYT7',
#  'LARS2',
#  'PIK3C2A',
#  'PLAUR',
#  'ANLN',
#  'WIZ',
#  'RABGAP1',
#  'DCN',
#  'QPCTL',
#  'PPP5C',
#  'CEP68',
#  'MAP4K3',
#  'ZBTB32',
#  'TYROBP',
#  'TMEM159',
#  'GABRA3',
#  'BRCA1',
#  'ERCC1',
#  'CD22',
#  'SEMA3B',
#  'MBTPS2',
#  'PRICKLE3',
#  'LTF',
#  'EXTL3',
#  'NR1H4',
#  'ELOVL5',
#  'ALOX5',
#  'KDM5D',
#  'CALCOCO1',
#  'UBR7',
#  'MAP4K5',
#  'EHD3',
#  'PSMC4',
#  'MAN2B2',
#  'SLC7A14',
#  'CLDN11',
#  'SLC25A39',
#  'MVP',
#  'NUB1',
#  'PGM3',
#  'RWDD2A',
#  'CLK1',
#  'POLR3B',
#  'ANGEL1',
#  'RNF14',
#  'DNASE1L1',
#  'DDX11',
#  'HEBP1',
#  'GPRC5A',
#  'MAMLD1',
#  'CD6',
#  'TACC3',
#  'UFL1',
#  'POLA2',
#  'ZC3H3',
#  'CAPN1',
#  'ACPP',
#  'MDH1',
#  'SLC30A9',
#  'MTMR11',
#  'COX15',
#  'CCDC88C',
#  'YAF2',
#  'ZMYND11',
#  'WAS',
#  'DPEP1',
#  'BID',
#  'MATR3',
#  'NPC1L1',
#  'XYLT2',
#  'RGPD5',
#  'STMN4',
#  'NUDCD3',
#  'ISL1',
#  'CHDH',
#  'IL20RA',
#  'CLCA1',
#  'CLCA4',
#  'GLT8D1',
#  'ATP2C1',
#  'SRCIN1',
#  'IGF1',
#  'SLC38A5',
#  'MAGIX',
#  'RALBP1',
#  'RUFY3',
#  'CNTN1',
#  'SLC11A1',
#  'WWTR1',
#  'AGPS',
#  'ZNF806',
#  'CXorf56',
#  'ATP1A2',
#  'TTC27',
#  'ZNF582',
#  'VSIG2',
#  'PHLDB1',
#  'MARCO',
#  'CYP24A1',
#  'PRDM11',
#  'SYT13',
#  'SNAI2',
#  'CD74',
#  'HGF',
#  'ZRANB1',
#  'NCDN',
#  'GPR124',
#  'CCT8L1P',
#  'ZFP64',
#  'MNAT1',
#  'SAMD4A',
#  'RUNX3',
#  'MRE11A',
#  'PLEKHB1',
#  'SERPINB1',
#  'CYP3A43',
#  'SLC7A9',
#  'SPAST',
#  'NRXN3',
#  'OSBPL5',
#  'AQR',
#  'CPS1',
#  'C8B',
#  'FHL1',
#  'RTFDC1',
#  'GABRA1',
#  'NLRP2',
#  'SLC45A4',
#  'RNF10',
#  'ZNF839',
#  'ZDHHC6',
#  'GRAMD1B',
#  'RNH1',
#  'NDUFS1',
#  'RB1CC1',
#  'ERP44',
#  'ALAS1',
#  'BIRC3',
#  'AKAP11',
#  'GLRX2',
#  'SNAPC1',
#  'DERA',
#  'STRAP',
#  'ABCC2',
#  'DEF6',
#  'PLEKHO1',
#  'GCLM',
#  'UBR2',
#  'EHD2',
#  'DEPDC1',
#  'CCDC28A',
#  'RRAGD',
#  'HSF2',
#  'PHF20',
#  'HSD17B6',
#  'NR1H3',
#  'TYMP',
#  'NCAPH2',
#  'TOMM34',
#  'SEC63',
#  'KPNA6',
#  'VIM',
#  'RTEL1-TNFRSF6B',
#  'FAS',
#  'RNASET2',
#  'CD44',
#  'KCNG1',
#  'AGPAT4',
#  'SLAMF7',
#  'BTN3A1',
#  'MIPEP',
#  'PRKCH',
#  'INSRR',
#  'IFNGR1',
#  'B4GALT7',
#  'SH2D2A',
#  'VRK2',
#  'TNFRSF1B',
#  'VEZT',
#  'POU2F2',
#  'BRD9',
#  'SNX1',
#  'TBPL1',
#  'ARNTL2',
#  'BCLAF1',
#  'SLC39A9',
#  'ANK1',
#  'IBSP',
#  'TFB1M',
#  'RABEP1',
#  'HMGB3',
#  'NUP160',
#  'BAK1',
#  'MUSK',
#  'IKZF2',
#  'GRN',
#  'FAM13B',
#  'ARHGAP31',
#  'NR2E3',
#  'CENPQ',
#  'SARS',
#  'RANBP3',
#  'ARID4A',
#  'TSSC1',
#  'PNPLA6',
#  'IFT88',
#  'ALG1',
#  'ZCCHC8',
#  'ABCF2',
#  'CHPF2',
#  'LRRC7',
#  'FUT8',
#  'UBA6',
#  'GAB2',
#  'ATP6V0A1',
#  'PIAS1',
#  'SLC4A7',
#  'APBA2',
#  'UHRF1',
#  'MAP2K3',
#  'EFCAB1',
#  'TMSB10',
#  'ASTE1',
#  'RNF19A',
#  'PEX3',
#  'GABARAPL2',
#  'MYOC',
#  'SH3YL1',
#  'FAM136A',
#  'VCL',
#  'DEPDC1B',
#  'DAPK2',
#  'NSMAF',
#  'ADSS',
#  'STAP1',
#  'TIMP2',
#  'RFC1',
#  'TBC1D23',
#  'CUL3',
#  'MYOM2',
#  'OTC',
#  'CYP46A1',
#  'ZZZ3',
#  'SLC18A1',
#  'USP2',
#  'CASR',
#  'TUBG2',
#  'RPL26L1',
#  'FLT4',
#  'NSUN2',
#  'FBXO42',
#  'MFAP3',
#  'MRI1',
#  'METTL1',
#  'HOXC8',
#  'AGA',
#  'PI4K2B',
#  'BOD1L1',
#  'MAT2B',
#  'TLL1',
#  'EDC4',
#  'TRIO',
#  'VCAN',
#  'CLEC16A',
#  'MSR1',
#  'CDH1',
#  'SKIV2L2',
#  'DNAH5',
#  'ZFYVE16',
#  'FAM65A',
#  'C6',
#  'RAI14',
#  'SOX30',
#  'PNKP',
#  'BEST2',
#  'PHLPP2',
#  'SPDL1',
#  'STAU2',
#  'PQLC2',
#  'CTNS',
#  'RTN4R',
#  'PHF23',
#  'CDH10',
#  'INPP4A',
#  'RAB27B',
#  'PSMA4',
#  'MYO16',
#  'LSG1',
#  'PARP3',
#  'TNC',
#  'THAP3',
#  'FAM65C',
#  'TDP1',
#  'AIFM2',
#  'C2orf83',
#  'SPATA7',
#  'MED17',
#  'RETSAT',
#  'CAPG',
#  'AP2S1',
#  'USH2A',
#  'ZPBP',
#  'TG',
#  'ADAM28',
#  'BARX2',
#  'DCUN1D1',
#  'PHF15',
#  'ZIC2',
#  'LCP2',
#  'TRIT1',
#  'ADRB1',
#  'GUCA2B',
#  'CUL7',
#  'CTNNA1',
#  'PHKA2',
#  'CNTLN',
#  'EPHA3',
#  'HSPA5',
#  'DSG2',
#  'GEMIN8',
#  'OFD1',
#  'GPM6B',
#  'MAGEC2',
#  'PREX2',
#  'WDR37',
#  'YTHDC2',
#  'CTPS2',
#  'ATP6V1H',
#  'POLR2B',
#  'FAM214A',
#  'ARAP2',
#  'TPR',
#  'CP',
#  'KIAA0556',
#  'DTNBP1',
#  'XK',
#  'ANO2',
#  'C12orf4',
#  'SCML1',
#  'WWC3',
#  'ARHGAP6',
#  'FAM184B',
#  'MAP4',
#  'GOPC',
#  'ROS1',
#  'USP28',
#  'HDAC9',
#  'TSPAN17',
#  'NOP16',
#  'CC2D2A',
#  'RRM2B',
#  'ZNF800',
#  'TNFRSF17',
#  'SNX29',
#  'LMO3',
#  'MRPS10',
#  'GUCA1A',
#  'RSF1',
#  'VPS13D',
#  'CELF2',
#  'FAM120A',
#  'R3HDM1',
#  'COL9A2',
#  'KITLG',
#  'ERCC8',
#  'ADAMTS6',
#  'H6PD',
#  'VAMP3',
#  'PER3',
#  'UTS2',
#  'TNFRSF9',
#  'EPN3',
#  'SRD5A2',
#  'LTBP1',
#  'RCN1',
#  'ELN',
#  'RFC2',
#  'ARID1B',
#  'CLPTM1L',
#  'NEDD4L',
#  'FOXP3',
#  'PPP1R3F',
#  'HEXB',
#  'PTCD2',
#  'KIAA2022',
#  'JKAMP',
#  'DKK3',
#  'ARHGEF5',
#  'NFE2L3',
#  'MCUR1',
#  'LIMA1',
#  'LETMD1',
#  'SLC4A8',
#  'LAMC3',
#  'PTGER3',
#  'TNIP3',
#  'MAPK9',
#  'COL23A1',
#  'BCAR1',
#  'FAM160A2',
#  'HERPUD1',
#  'HOMER3',
#  'RAD51',
#  'POLQ',
#  'PIK3CB',
#  'CYBA',
#  'THOC3',
#  'HEBP2',
#  'MPHOSPH9',
#  'PLEKHA5',
#  'PRSS8',
#  'SIKE1',
#  'RRP12',
#  'FNIP2',
#  'MSMO1',
#  'TTC17',
#  'ALX4',
#  'FSTL4',
#  'FOXN3',
#  'METTL24',
#  'AKR7A2',
#  'MRTO4',
#  'NNAT',
#  'USE1',
#  'MCF2L2',
#  'NRIP2',
#  'LAMA3',
#  'AP5M1',
#  'ANAPC4',
#  'KCNQ1',
#  'TRAPPC3',
#  'THRAP3',
#  'PHPT1',
#  'ENTPD2',
#  'LY75',
#  'ARID4B',
#  'OPN3',
#  'SDCCAG8',
#  'PTPRN',
#  'HHAT',
#  'KIF1B',
#  'FOXC1',
#  'TBC1D22A',
#  'SYNE2',
#  'PLEKHH1',
#  'ATP9A',
#  'SPO11',
#  'CBLN4',
#  'CHRDL2',
#  'FAM168A',
#  'RELT',
#  'GALC',
#  'NOP58',
#  'SZRD1',
#  'KCNH2',
#  'CUL1',
#  'FAM114A2',
#  'CYFIP2',
#  'TAB2',
#  'GINM1',
#  'EIF2AK2',
#  'USP36',
#  'KMT2C',
#  'MCOLN3',
#  'CCDC85A',
#  'PUM2',
#  'MRPL43',
#  'ITIH4',
#  'ITIH1',
#  'C4orf27',
#  'ZFR',
#  'ZNF280C',
#  'NPFFR2',
#  'PHF21B',
#  'TRAF1',
#  'RC3H2',
#  'PCGF2',
#  'IL17RB',
#  'TRAF3IP2',
#  'GYG2',
#  'DCBLD2',
#  'SERPINB3',
#  'SOAT1',
#  'PKP2',
#  'MSH4',
#  'F7',
#  'GDI2',
#  'PRDM1',
#  'ATG5',
#  'TMCC3',
#  'PITHD1',
#  'MTA3',
#  'USP13',
#  'ATP11B',
#  'LAMC2',
#  'CDK14',
#  'SEC61A1',
#  'PPP1R12A',
#  'RASGRF1',
#  'CAMK2B',
#  'CROCC',
#  'POLR3E',
#  'ATP2B4',
#  'ZC3H11A',
#  'RIOK2',
#  'YIPF1',
#  'NDC1',
#  'DGKG',
#  'FLYWCH1',
#  'UNKL',
#  'TBXAS1',
#  'PARP12',
#  'ALDH18A1',
#  'TARBP1',
#  'PET112',
#  'MXD1',
#  'CDK17',
#  'DNAJC25',
#  'SLC2A3',
#  'PSD',
#  'CTDP1',
#  'YBX3',
#  'STYK1',
#  'WNK1',
#  'RPS17P5',
#  'CCAR1',
#  'OGFR',
#  'GNA15',
#  'CREB3L3',
#  'PIGV',
#  'PTPRU',
#  'SNRNP40',
#  'RIMBP2',
#  'COL11A1',
#  'QSER1',
#  'MPC1',
#  'ACAA1',
#  'BCAT1',
#  'HDAC7',
#  'LZTS1',
#  'PRDM6',
#  'WNT8A',
#  'SPAG4',
#  'NCKAP1',
#  'MRPS35',
#  'GUCY1B3',
#  'SFSWAP',
#  'TNK2',
#  'MON2',
#  'CDH3',
#  'ARSF',
#  'GPBP1',
#  'DGAT2',
#  'ZNF112',
#  'CS',
#  'LTK',
#  'MRPS24',
#  'ELMO2',
#  'WAPAL',
#  'VMP1',
#  'APPBP2',
#  'POLD1',
#  'SEZ6',
#  'EIF4B',
#  'SLC6A16',
#  'GLTSCR1',
#  'SPHK2',
#  'RPL18',
#  'CA11',
#  'ISOC2',
#  'U2AF2',
#  'EPN1',
#  'MED29',
#  'AHRR',
#  'GSC2',
#  'ZNF275',
#  'MTMR1',
#  'GPC1',
#  'ADCK1',
#  'HAGH',
#  'RNF4',
#  'CASP8',
#  'LIMCH1',
#  'ASUN',
#  'TM7SF3',
#  'DLX3',
#  'SPA17',
#  'TSPAN32',
#  'WISP2',
#  'DMRT3',
#  'ST3GAL6',
#  'ATP2C2',
#  'NGFR',
#  'CDON',
#  'TAF2',
#  'HIPK2',
#  'TNPO3',
#  'MEF2BNB-MEF2B',
#  'RFXANK',
#  'TMEM161A',
#  'LPAR2',
#  'CTSA',
#  'SUGP2',
#  'SLC12A2',
#  'SNX24',
#  'EYA2',
#  'CNN2',
#  'ABCA7',
#  'SNCAIP',
#  'DDX20',
#  'BTBD1',
#  'FAR2',
#  'BCAS1',
#  'POU1F1',
#  'CHI3L2',
#  'SBNO2',
#  'PMS1',
#  'HMG20B',
#  'CALCRL',
#  'TAF11',
#  'ANKS1A',
#  'AP3D1',
#  'ZNF76',
#  'SLC9A3R2',
#  'NTHL1',
#  'UHRF1BP1',
#  'GNAI3',
#  'IPO5',
#  'OAT',
#  'WDR3',
#  'PKN2',
#  'WDR18',
#  'TRAM2',
#  'NTN1',
#  'GLP2R',
#  'MCM10',
#  'DGKA',
#  'ERBB3',
#  'ROPN1',
#  'ANKRD44',
#  'KARS',
#  'ADAT1',
#  'PDIA5',
#  'TBC1D22B',
#  'NDUFB4',
#  'SPEN',
#  'MYLK',
#  'ZC3H15',
#  'MAP2K4',
#  'TMEM206',
#  'SNAP91',
#  'SLK',
#  'CYB5R4',
#  'COL17A1',
#  'GSTO2',
#  'SEC61A2',
#  'PRKCQ',
#  'TLE2',
#  'ASB1',
#  'FAM107B',
#  'ME1',
#  'TBC1D1',
#  'CDK13',
#  'MTHFD2',
#  'SLC9A7',
#  'FOXJ2',
#  'YBX1',
#  'PDE4A',
#  'PPP2R5A',
#  'CTNNA2',
#  'ELAVL1',
#  'TIE1',
#  'DIP2B',
#  'SMARCD1',
#  'KDM4A',
#  'NFYC',
#  'ZMYND12',
#  'SLC9A3',
#  'NGEF',
#  'ASPM',
#  'CD84',
#  'ELOVL1',
#  'SPI1',
#  'ZNRD1',
#  'MPPED2',
#  'CLDN18',
#  'ZBTB11',
#  'ATXN3',
#  'GOLGA5',
#  'FGFR2',
#  'LRRC40',
#  'ISOC1',
#  'EML1',
#  'TRMT11',
#  'THUMPD1',
#  'MSANTD3',
#  'KIF26A',
#  'ATG2B',
#  'ARFGEF1',
#  'ACSM2B',
#  'ZFAT',
#  'MTFR1',
#  'STAG3',
#  ...]

# %%
print(len(gene_names_list))
# Out:
# 55737

# %%
# read data
adata = pd.read_csv("../01-data/GSE120575_Sade_Feldman_melanoma_single_cells_TPM_GEO.txt", delimiter="\t",skiprows=[1], usecols=index3_list, header=0).T

print(adata.shape)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 # read data
# ----> 2 adata = pd.read_csv("../01-data/GSE120575_Sade_Feldman_melanoma_single_cells_TPM_GEO.txt", delimiter="\t",skiprows=[1], usecols=index3_list, header=0).T
#       4 print(adata.shape)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\envs\scrnaseq\lib\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
bdata = adata.to_numpy()
print(bdata.shape)
bdata

# %%
# create sparse matrix using csr_matrix()
  
# Import required package
from scipy.sparse import csr_matrix
  
# creating sparse matrix
sparseMatrix = sparse.csr_matrix(bdata)
              
# print the sparse matrix
print(sparseMatrix)

# %%
type(sparseMatrix)
sparse.isspmatrix(sparseMatrix)

# %%
sio.mmwrite("../01-data/matrix/matrix.mtx",sparseMatrix)

# %%
print(gene_names.shape)
gene_names2 = gene_names.iloc[1:,:]
gene_names2

# %%
gene_names2.to_csv('../01-data/matrix/genes.tsv', index=False)

# %%
combo_index.to_csv('../01-data/matrix/barcodes.tsv')
